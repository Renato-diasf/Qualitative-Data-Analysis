# %% [markdown]
# <h1/>Análise de Dados Qualitativos<h1/>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("dados.csv")

# %%
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
est = {
    11: "Rondônia",
    12: "Acre",
    13: "Amazonas",
    14: "Roraima",
    15: "Pará",
    16: "Amapá",
    17: "Tocantins",
    21: "Maranhão",
    22: "Piauí",
    23: "Ceará",
    24: "Rio Grande do Norte",
    25: "Paraíba",
    26: "Pernambuco",
    27: "Alagoas",
    28: "Sergipe",
    29: "Bahia",
    31: "Minas Gerais",
    32: "Espírito Santo",
    33: "Rio de Janeiro",
    35: "São Paulo",
    41: "Paraná",
    42: "Santa Catarina",
    43: "Rio Grande do Sul",
    50: "Mato Grosso do Sul",
    51: "Mato Grosso",
    52: "Goiás",
    53: "Distrito Federal"
}

# %% [markdown]
# <h3/>Distribuição de Frequência e Porcetagem<h3/>

# %%
freq = dados.Sexo.value_counts()

# %%
porc = dados.Sexo.value_counts(normalize = True)

# %%
separacao_sexo = pd.DataFrame({"Frequência": freq, "Porcentagem": porc})
separacao_sexo
# Out:
#    Frequência  Porcentagem
# 0       53250     0.692998
# 1       23590     0.307002

# %%
separacao_sexo.rename(index = {0: "Masculino", 1: "Feminino"}, inplace = True)
separacao_sexo
# Out:
#            Frequência  Porcentagem
# Masculino       53250     0.692998
# Feminino        23590     0.307002

# %%
plt.figure(figsize = (12, 6))

plt.title("Distribuição de Frequência das Pessoas Entrevistadas")

separacao_sexo["Frequência"].plot(kind = 'bar', color = '#607196')
# Out:
# <Axes: title={'center': 'Distribuição de Frequência das Pessoas Entrevistadas'}>

# %% [markdown]
# <h3/>Contagem de Pessoas por Estado<h3/>

# %%
frequencia = dados["UF"].value_counts().sort_values(ascending = False)
separacao_estado = frequencia.to_frame()
separacao_estado.rename(index = est, inplace = True)
separacao_estado.reset_index(inplace = True)
separacao_estado.rename(columns = {"index": "Estados", "UF": "Contagem"}, inplace = True )

# %%
separacao_estado.set_index("Estados")
# Out:
#                      Contagem
# Estados
# São Paulo                8544
# Minas Gerais             7686
# Rio Grande do Sul        6322
# Bahia                    5717
# Rio de Janeiro           5556
# Pará                     4449
# Paraná                   4356
# Pernambuco               3820
# Goiás                    3478
# Ceará                    3359
# Santa Catarina           2275
# Amazonas                 2206
# Distrito Federal         2054
# Mato Grosso              1800
# Maranhão                 1787
# Rondônia                 1537
# Espírito Santo           1511
# Mato Grosso do Sul       1440
# Tocantins                1306
# Sergipe                  1287
# Paraíba                  1274
# Piauí                    1211
# Rio Grande do Norte       973
# Acre                      937
# Alagoas                   903
# Roraima                   540
# Amapá                     512

# %%
porcentagem = dados["UF"].value_counts(normalize = True).sort_values(ascending = False) * 100
separacao_estado = porcentagem.to_frame()
separacao_estado.rename(index = est, inplace = True)
separacao_estado.reset_index(inplace = True)
separacao_estado.rename(columns = {"index": "Estados", "UF": "Porcentagem"}, inplace = True )
separacao_estado.set_index("Estados")
# Out:
#                      Porcentagem
# Estados
# São Paulo              11.119209
# Minas Gerais           10.002603
# Rio Grande do Sul       8.227486
# Bahia                   7.440135
# Rio de Janeiro          7.230609
# Pará                    5.789953
# Paraná                  5.668922
# Pernambuco              4.971369
# Goiás                   4.526288
# Ceará                   4.371421
# Santa Catarina          2.960698
# Amazonas                2.870901
# Distrito Federal        2.673087
# Mato Grosso             2.342530
# Maranhão                2.325612
# Rondônia                2.000260
# Espírito Santo          1.966424
# Mato Grosso do Sul      1.874024
# Tocantins               1.699636
# Sergipe                 1.674909
# Paraíba                 1.657991
# Piauí                   1.576002
# Rio Grande do Norte     1.266268
# Acre                    1.219417
# Alagoas                 1.175169
# Roraima                 0.702759
# Amapá                   0.666320

# %%
pop_estados = pd.DataFrame({"Frequência": frequencia, "Porcentagem(%)": porcentagem})
pop_estados.rename(index = est, inplace = True)

# %%
pop_estados.index.name = "Estados"
pop_estados
# Out:
#                      Frequência  Porcentagem(%)
# Estados
# São Paulo                  8544       11.119209
# Minas Gerais               7686       10.002603
# Rio Grande do Sul          6322        8.227486
# Bahia                      5717        7.440135
# Rio de Janeiro             5556        7.230609
# Pará                       4449        5.789953
# Paraná                     4356        5.668922
# Pernambuco                 3820        4.971369
# Goiás                      3478        4.526288
# Ceará                      3359        4.371421
# Santa Catarina             2275        2.960698
# Amazonas                   2206        2.870901
# Distrito Federal           2054        2.673087
# Mato Grosso                1800        2.342530
# Maranhão                   1787        2.325612
# Rondônia                   1537        2.000260
# Espírito Santo             1511        1.966424
# Mato Grosso do Sul         1440        1.874024
# Tocantins                  1306        1.699636
# Sergipe                    1287        1.674909
# Paraíba                    1274        1.657991
# Piauí                      1211        1.576002
# Rio Grande do Norte         973        1.266268
# Acre                        937        1.219417
# Alagoas                     903        1.175169
# Roraima                     540        0.702759
# Amapá                       512        0.666320

# %%
plt.figure(figsize = (12, 6))

plt.title("Distribuição por Estado das Pessoas Entrevistadas")

pop_estados["Frequência"].plot(kind = 'bar', color = '#332C23')
# Out:
# <Axes: title={'center': 'Distribuição por Estado das Pessoas Entrevistadas'}, xlabel='Estados'>

# %% [markdown]
# <h3/>Distribuição pelos Anos de Estudo<h3/>

# %%
frequencia = dados["Anos de Estudo"].value_counts().sort_index()
frequencia
# Out:
# 1      5849
# 2      1388
# 3      2101
# 4      2891
# 5      6729
# 6      4499
# 7      2445
# 8      2689
# 9      7980
# 10     1840
# 11     2118
# 12    20848
# 13     1836
# 14     1253
# 15     1388
# 16    10795
# 17      191
# Name: Anos de Estudo, dtype: int64

# %%
porcentagem = dados["Anos de Estudo"].value_counts(normalize = True).sort_index() * 100
porcentagem
# Out:
# 1      7.611921
# 2      1.806351
# 3      2.734253
# 4      3.762363
# 5      8.757158
# 6      5.855023
# 7      3.181936
# 8      3.499479
# 9     10.385216
# 10     2.394586
# 11     2.756377
# 12    27.131702
# 13     2.389381
# 14     1.630661
# 15     1.806351
# 16    14.048673
# 17     0.248568
# Name: Anos de Estudo, dtype: float64

# %%
dist_anos_de_estudo = pd.DataFrame({"Frequência": frequencia, "Porcentagem(%)": porcentagem})
dist_anos_de_estudo.index.name = "Anos de Estudo"
dist_anos_de_estudo
# Out:
#                 Frequência  Porcentagem(%)
# Anos de Estudo
# 1                     5849        7.611921
# 2                     1388        1.806351
# 3                     2101        2.734253
# 4                     2891        3.762363
# 5                     6729        8.757158
# 6                     4499        5.855023
# 7                     2445        3.181936
# 8                     2689        3.499479
# 9                     7980       10.385216
# 10                    1840        2.394586
# 11                    2118        2.756377
# 12                   20848       27.131702
# 13                    1836        2.389381
# 14                    1253        1.630661
# 15                    1388        1.806351
# 16                   10795       14.048673
# 17                     191        0.248568

# %%
plt.figure(figsize = (12, 6))

plt.title("Distribuição por Anos de Estudo das Pessoas Entrevistadas")

dist_anos_de_estudo["Frequência"].plot(kind = 'bar', color = '#B3001B')
# Out:
# <Axes: title={'center': 'Distribuição por Anos de Estudo das Pessoas Entrevistadas'}, xlabel='Anos de Estudo'>

# %% [markdown]
# <h3/>Distribuição pela Cor<h3/>

# %%
frequencia = dados.Cor.value_counts()
frequencia
# Out:
# 8    35925
# 2    31815
# 4     8391
# 0      357
# 6      352
# Name: Cor, dtype: int64

# %%
porcentagem = dados.Cor.value_counts(normalize = True) * 100
porcentagem
# Out:
# 8    46.752993
# 2    41.404217
# 4    10.920094
# 0     0.464602
# 6     0.458095
# Name: Cor, dtype: float64

# %%
dist_cor = pd.DataFrame({"Frequência": frequencia, "Porcentagem(%)": porcentagem})
dist_cor.index = dist_cor.index.map({0: "Indígena",
2: "Branca",
4: "Preta",
6: "Amarela",
8: "Parda"})
dist_cor.index.name = "Cor"

# %%
dist_cor
# Out:
#           Frequência  Porcentagem(%)
# Cor
# Parda          35925       46.752993
# Branca         31815       41.404217
# Preta           8391       10.920094
# Indígena         357        0.464602
# Amarela          352        0.458095

# %%
plt.figure(figsize = (12, 6))

plt.title("Distribuição pela Cor das Pessoas Entrevistadas")

dist_cor["Frequência"].plot(kind = 'bar', color = '#607196')
# Out:
# <Axes: title={'center': 'Distribuição pela Cor das Pessoas Entrevistadas'}, xlabel='Cor'>

# %% [markdown]
# <h3/>Cruzamento de Valores<h3/>

# %%
cor = {0: 'Indígena', 
       2: 'Branca', 
       4: 'Preta', 
       6: 'Amarela', 
       8: 'Parda', 
       9: 'Sem declaração'}

# %%
frequencia = pd.crosstab(dados.Cor,
                         dados["UF"])
frequencia.rename(index = cor, inplace = True)
frequencia.rename(columns = est, inplace = True)
frequencia
# Out:
# UF        Rondônia  Acre  Amazonas  Roraima  Pará  Amapá  Tocantins  Maranhão  \
# Cor
# Indígena         3    27        58       20    44      1          0         9
# Branca         492   190       343       96   790    104        312       343
# Preta          165    92       123       61   466     50        164       269
# Amarela          9     2         6        1    14      3          4         1
# Parda          868   626      1676      362  3135    354        826      1165
#
# UF        Piauí  Ceará  ...  Espírito Santo  Rio de Janeiro  São Paulo  \
# Cor                     ...
# Indígena      1     14  ...               5              12         27
# Branca      233    879  ...             641            2488       5047
# Preta       151    186  ...             181             927        705
# Amarela       0     12  ...               1              19        120
# Parda       826   2268  ...             683            2110       2645
#
# UF        Paraná  Santa Catarina  Rio Grande do Sul  Mato Grosso do Sul  \
# Cor
# Indígena       6               5                 27                   7
# Branca      2966            1930               5083                 639
# Preta        193              52                444                  82
# Amarela       53               3                  9                  14
# Parda       1138             285                759                 698
#
# UF        Mato Grosso  Goiás  Distrito Federal
# Cor
# Indígena            6      5                 4
# Branca            614   1283               861
# Preta             168    327               233
# Amarela             8     31                12
# Parda            1004   1832               944
#
# [5 rows x 27 columns]

# %%
frequencia_porc = frequencia / pop_estados["Frequência"] * 100
frequencia_porc
# Out:
#                Acre    Alagoas      Amapá   Amazonas      Bahia      Ceará  \
# Cor
# Indígena   2.881537   0.442968   0.195312   2.629193   0.542242   0.416791
# Branca    20.277481  27.242525  20.312500  15.548504  17.001924  26.168503
# Preta      9.818570  11.406423   9.765625   5.575703  28.214098   5.537362
# Amarela    0.213447   0.000000   0.585938   0.271985   0.104950   0.357249
# Parda     66.808965  60.908084  69.140625  75.974615  54.136785  67.520095
#
#           Distrito Federal  Espírito Santo      Goiás   Maranhão  ...  \
# Cor                                                               ...
# Indígena          0.194742        0.330907   0.143761   0.503637  ...
# Branca           41.918208       42.422237  36.889017  19.194180  ...
# Preta            11.343720       11.978822   9.401955  15.053162  ...
# Amarela           0.584226        0.066181   0.891317   0.055960  ...
# Parda            45.959104       45.201853  52.673951  65.193061  ...
#
#               Piauí  Rio Grande do Norte  Rio Grande do Sul  Rio de Janeiro  \
# Cor
# Indígena   0.082576             0.000000           0.427080        0.215983
# Branca    19.240297            37.512847          80.401772       44.780418
# Preta     12.469034             7.194245           7.023094       16.684665
# Amarela    0.000000             0.000000           0.142360        0.341973
# Parda     68.208092            55.292909          12.005694       37.976962
#
#            Rondônia    Roraima  Santa Catarina    Sergipe  São Paulo  \
# Cor
# Indígena   0.195185   3.703704        0.219780   0.077700   0.316011
# Branca    32.010410  17.777778       84.835165  21.989122  59.070693
# Preta     10.735198  11.296296        2.285714  10.178710   8.251404
# Amarela    0.585556   0.185185        0.131868   0.233100   1.404494
# Parda     56.473650  67.037037       12.527473  67.521368  30.957397
#
#           Tocantins
# Cor
# Indígena   0.000000
# Branca    23.889740
# Preta     12.557427
# Amarela    0.306279
# Parda     63.246554
#
# [5 rows x 27 columns]

# %%
frequencia_porc[["Acre", "Amazonas", "Alagoas", "Rio de Janeiro", "São Paulo", "Minas Gerais", "Rio Grande do Sul"]]
# Out:
#                Acre   Amazonas    Alagoas  Rio de Janeiro  São Paulo  \
# Cor
# Indígena   2.881537   2.629193   0.442968        0.215983   0.316011
# Branca    20.277481  15.548504  27.242525       44.780418  59.070693
# Preta      9.818570   5.575703  11.406423       16.684665   8.251404
# Amarela    0.213447   0.271985   0.000000        0.341973   1.404494
# Parda     66.808965  75.974615  60.908084       37.976962  30.957397
#
#           Minas Gerais  Rio Grande do Sul
# Cor
# Indígena      0.208171           0.427080
# Branca       40.281030          80.401772
# Preta        12.125943           7.023094
# Amarela       0.078064           0.142360
# Parda        47.306792          12.005694

# %%
frequencia = pd.crosstab(dados["Anos de Estudo"],
                         dados["UF"])
frequencia.rename(columns = est, inplace = True)
frequencia
# Out:
# UF              Rondônia  Acre  Amazonas  Roraima  Pará  Amapá  Tocantins  \
# Anos de Estudo
# 1                    118   189       181       53   393     30        123
# 2                     41    18        54       10   108      8         41
# 3                     55    17        72       10   170     10         44
# 4                     73    34        76       17   273     17         72
# 5                    174    66       138       29   356     37         88
# 6                    105    36       148       21   291     21         89
# 7                     55    10        73       19   161     16         39
# 8                     53    25        83       19   155     14         29
# 9                    173   109       207       44   502     58        129
# 10                    42    21        56        9   113     17         41
# 11                    41    36        65       18   181     16         41
# 12                   355   216       672      156  1205    159        331
# 13                    25    22        39       15    52      8         21
# 14                    23    13        31       11    42     10         20
# 15                    26    10        42       21    49     12         30
# 16                   173   111       256       88   385     76        167
# 17                     5     4        13        0    13      3          1
#
# UF              Maranhão  Piauí  Ceará  ...  Espírito Santo  Rio de Janeiro  \
# Anos de Estudo                          ...
# 1                    322    243    416  ...              94             217
# 2                     86     44    104  ...              24              44
# 3                     95     74    113  ...              38              93
# 4                     76     79    145  ...              44             136
# 5                    147    154    203  ...             186             334
# 6                    100     61    184  ...              93             281
# 7                     49     34     97  ...              39             157
# 8                     62     32    114  ...              56             181
# 9                    162     80    401  ...             164             747
# 10                    43     40     83  ...              34             100
# 11                    51     28     94  ...              42             174
# 12                   407    206    952  ...             397            1653
# 13                    34     18     49  ...              39             228
# 14                    13      9     47  ...              19              82
# 15                    22      9     57  ...              27              86
# 16                   114    100    294  ...             212            1035
# 17                     4      0      6  ...               3               8
#
# UF              São Paulo  Paraná  Santa Catarina  Rio Grande do Sul  \
# Anos de Estudo
# 1                     318     223              78                176
# 2                      60      30              15                 72
# 3                     102      89              32                124
# 4                     208     137              50                215
# 5                     684     453             279                469
# 6                     392     227              91                604
# 7                     237     123              44                269
# 8                     251     124              67                225
# 9                     925     465             340                720
# 10                    189      87              38                161
# 11                    212     129              52                172
# 12                   2723    1194             648               1547
# 13                    198     125              84                184
# 14                    207      92              43                130
# 15                    229     114              43                152
# 16                   1598     724             357               1095
# 17                     11      20              14                  7
#
# UF              Mato Grosso do Sul  Mato Grosso  Goiás  Distrito Federal
# Anos de Estudo
# 1                               77          135    207                73
# 2                               36           28     55                12
# 3                               50           48     91                12
# 4                               45           63    128                32
# 5                              142          146    292                92
# 6                               89          115    234                73
# 7                               62           54    149                41
# 8                               62           53    166                55
# 9                              146          222    386               132
# 10                              40           44     94                31
# 11                              28           57    116                45
# 12                             364          482    938               597
# 13                              24           57     90                47
# 14                              20           30     53                59
# 15                              27           28     46                71
# 16                             223          234    428               675
# 17                               5            4      5                 7
#
# [17 rows x 27 columns]

# %%
frequencia_porc = frequencia/ pop_estados["Frequência"] * 100
frequencia_porc
# Out:
#                      Acre    Alagoas      Amapá   Amazonas      Bahia  \
# Anos de Estudo
# 1               20.170758  14.507198   5.859375   8.204896  11.964317
# 2                1.921025   2.879291   1.562500   2.447869   2.396362
# 3                1.814301   6.201550   1.953125   3.263826   3.305930
# 4                3.628602   5.094131   3.320312   3.445150   4.355431
# 5                7.043757   9.191584   7.226562   6.255666   7.906245
# 6                3.842049   7.198228   4.101562   6.708976   6.227042
# 7                1.067236   3.211517   3.125000   3.309157   3.393388
# 8                2.668090   6.423034   2.734375   3.762466   3.778205
# 9               11.632871   7.973422  11.328125   9.383500   7.049152
# 10               2.241195   3.100775   3.320312   2.538531   2.763687
# 11               3.842049   1.439646   3.125000   2.946510   2.816162
# 12              23.052295  18.826135  31.054688  30.462375  29.858317
# 13               2.347919   1.107420   1.562500   1.767906   2.029036
# 14               1.387407   0.996678   1.953125   1.405258   1.364352
# 15               1.067236   1.218162   2.343750   1.903898   1.241910
# 16              11.846318  10.299003  14.843750  11.604714   9.218121
# 17               0.426894   0.332226   0.585938   0.589302   0.332342
#
#                     Ceará  Distrito Federal  Espírito Santo      Goiás  \
# Anos de Estudo
# 1               12.384638          3.554041        6.221046   5.951696
# 2                3.096160          0.584226        1.588352   1.581369
# 3                3.364096          0.584226        2.514891   2.616446
# 4                4.316761          1.557936        2.911979   3.680276
# 5                6.043465          4.479065       12.309729   8.395630
# 6                5.477821          3.554041        6.154864   6.728005
# 7                2.887764          1.996105        2.581072   4.284071
# 8                3.393867          2.677702        3.706155   4.772858
# 9               11.938077          6.426485       10.853739  11.098332
# 10               2.470974          1.509250        2.250165   2.702703
# 11               2.798452          2.190847        2.779616   3.335250
# 12              28.341768         29.065239       26.273991  26.969523
# 13               1.458767          2.288218        2.581072   2.587694
# 14               1.399226          2.872444        1.257445   1.523864
# 15               1.696934          3.456670        1.786896   1.322599
# 16               8.752605         32.862707       14.030443  12.305923
# 17               0.178625          0.340798        0.198544   0.143761
#
#                  Maranhão  ...      Piauí  Rio Grande do Norte  \
# Anos de Estudo             ...
# 1               18.019026  ...  20.066061            10.894142
# 2                4.812535  ...   3.633361             4.008222
# 3                5.316172  ...   6.110652             3.083248
# 4                4.252938  ...   6.523534             4.213772
# 5                8.226077  ...  12.716763             7.194245
# 6                5.595971  ...   5.037159             5.652621
# 7                2.742026  ...   2.807597             3.288798
# 8                3.469502  ...   2.642444             3.905447
# 9                9.065473  ...   6.606111             8.016444
# 10               2.406267  ...   3.303055             3.391572
# 11               2.853945  ...   2.312139             4.008222
# 12              22.775602  ...  17.010735            26.515930
# 13               1.902630  ...   1.486375             1.644399
# 14               0.727476  ...   0.743187             1.027749
# 15               1.231114  ...   0.743187             1.541624
# 16               6.379407  ...   8.257638            11.510791
# 17               0.223839  ...   0.000000             0.102775
#
#                 Rio Grande do Sul  Rio de Janeiro   Rondônia    Roraima  \
# Anos de Estudo
# 1                        2.783929        3.905688   7.677293   9.814815
# 2                        1.138880        0.791937   2.667534   1.851852
# 3                        1.961405        1.673866   3.578399   1.851852
# 4                        3.400823        2.447804   4.749512   3.148148
# 5                        7.418538        6.011519  11.320755   5.370370
# 6                        9.553939        5.057595   6.831490   3.888889
# 7                        4.254983        2.825774   3.578399   3.518519
# 8                        3.559000        3.257739   3.448276   3.518519
# 9                       11.388801       13.444924  11.255693   8.148148
# 10                       2.546662        1.799856   2.732596   1.666667
# 11                       2.720658        3.131749   2.667534   3.333333
# 12                      24.470104       29.751620  23.096942  28.888889
# 13                       2.910471        4.103672   1.626545   2.777778
# 14                       2.056311        1.475882   1.496422   2.037037
# 15                       2.404302        1.547876   1.691607   3.888889
# 16                      17.320468       18.628510  11.255693  16.296296
# 17                       0.110724        0.143988   0.325309   0.000000
#
#                 Santa Catarina    Sergipe  São Paulo  Tocantins
# Anos de Estudo
# 1                     3.428571  16.627817   3.721910   9.418070
# 2                     0.659341   4.662005   0.702247   3.139357
# 3                     1.406593   5.982906   1.193820   3.369066
# 4                     2.197802   6.604507   2.434457   5.513017
# 5                    12.263736   9.090909   8.005618   6.738132
# 6                     4.000000   5.361305   4.588015   6.814701
# 7                     1.934066   4.584305   2.773876   2.986217
# 8                     2.945055   3.962704   2.937734   2.220521
# 9                    14.945055   7.226107  10.826311   9.877489
# 10                    1.670330   2.564103   2.212079   3.139357
# 11                    2.285714   2.641803   2.481273   3.139357
# 12                   28.483516  20.823621  31.870318  25.344564
# 13                    3.692308   1.165501   2.317416   1.607963
# 14                    1.890110   0.466200   2.422753   1.531394
# 15                    1.890110   1.010101   2.680243   2.297090
# 16                   15.692308   7.226107  18.703184  12.787136
# 17                    0.615385   0.000000   0.128745   0.076570
#
# [17 rows x 27 columns]

# %%
frequencia_porc[["Acre", "Amazonas", "Alagoas", "Rio de Janeiro", "São Paulo", "Minas Gerais", "Rio Grande do Sul"]]
# Out:
#                      Acre   Amazonas    Alagoas  Rio de Janeiro  São Paulo  \
# Anos de Estudo
# 1               20.170758   8.204896  14.507198        3.905688   3.721910
# 2                1.921025   2.447869   2.879291        0.791937   0.702247
# 3                1.814301   3.263826   6.201550        1.673866   1.193820
# 4                3.628602   3.445150   5.094131        2.447804   2.434457
# 5                7.043757   6.255666   9.191584        6.011519   8.005618
# 6                3.842049   6.708976   7.198228        5.057595   4.588015
# 7                1.067236   3.309157   3.211517        2.825774   2.773876
# 8                2.668090   3.762466   6.423034        3.257739   2.937734
# 9               11.632871   9.383500   7.973422       13.444924  10.826311
# 10               2.241195   2.538531   3.100775        1.799856   2.212079
# 11               3.842049   2.946510   1.439646        3.131749   2.481273
# 12              23.052295  30.462375  18.826135       29.751620  31.870318
# 13               2.347919   1.767906   1.107420        4.103672   2.317416
# 14               1.387407   1.405258   0.996678        1.475882   2.422753
# 15               1.067236   1.903898   1.218162        1.547876   2.680243
# 16              11.846318  11.604714  10.299003       18.628510  18.703184
# 17               0.426894   0.589302   0.332226        0.143988   0.128745
#
#                 Minas Gerais  Rio Grande do Sul
# Anos de Estudo
# 1                   6.023940           2.783929
# 2                   1.301067           1.138880
# 3                   3.096539           1.961405
# 4                   4.527713           3.400823
# 5                  14.884205           7.418538
# 6                   5.087171           9.553939
# 7                   3.343742           4.254983
# 8                   4.267499           3.559000
# 9                  10.161332          11.388801
# 10                  2.289878           2.546662
# 11                  2.159771           2.720658
# 12                 24.915431          24.470104
# 13                  1.873536           2.910471
# 14                  1.366120           2.056311
# 15                  1.574291           2.404302
# 16                 12.893573          17.320468
# 17                  0.234192           0.110724
